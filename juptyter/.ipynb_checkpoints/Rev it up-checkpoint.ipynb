# %% [markdown]
# ### Stuff below installs kaggle and the dataset :)

# %%
pip install kaggle
# Out:
# ...
#   Using cached kaggle-1.6.17.tar.gz (82 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for kaggle: filename=kaggle-1.6.17-py3-none-any.whl size=105795 sha256=58a953794315fad5df2862aed01427bceb59ec3e339b690eee88ebd0a89a83ff
#   Stored in directory: c:\users\kiers\appdata\local\pip\cache\wheels\46\d2\26\84d0a1acdb9c6baccf7d28cf06962ec80529fe1ad938489983
# Successfully built kaggle
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !kaggle datasets download -d maharshipandya/-spotify-tracks-dataset
# Out:
# Dataset URL: https://www.kaggle.com/datasets/maharshipandya/-spotify-tracks-dataset
# License(s): ODbL-1.0
# ...
#   0%|          | 0.00/8.17M [00:00<?, ?B/s]
#  12%|#2        | 1.00M/8.17M [00:00<00:01, 7.38MB/s]
#  24%|##4       | 2.00M/8.17M [00:00<00:00, 8.72MB/s]
#  37%|###6      | 3.00M/8.17M [00:00<00:00, 9.30MB/s]
#  61%|######1   | 5.00M/8.17M [00:00<00:00, 10.0MB/s]
#  86%|########5 | 7.00M/8.17M [00:00<00:00, 10.8MB/s]
# 100%|##########| 8.17M/8.17M [00:00<00:00, 11.1MB/s]
# 100%|##########| 8.17M/8.17M [00:00<00:00, 10.3MB/s]

# %% [markdown]
# ### Importing more stuff

# %%
import pandas as pd #importing pandas software

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.neighbors import NearestNeighbors
from sklearn.preprocessing import StandardScaler

# %%
import os

# %%
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

# %%
cwd = os.getcwd()
file_path=os.path.join(cwd, 'dataset.csv')
data = pd.read_csv('/Users/kiers/Downloads/Howdy Hack 24/-spotify-tracks-dataset/dataset.csv')

# %%
#value=data.iloc[2,1]
#print(value) #test to make sure it uploaded right, it did

# %%
genre_dictionary={'acoustic': '1',
'afrobeat': '2',
'alt-rock': '3',
'alternative': '4',
'ambient': '5',
'anime': '6',
'black-metal': '7',
'bluegrass': '8',
'blues': '9',
'brazil': '10',
'breakbeat': '11',
'british': '12',
'cantopop': '13',
'chicago-house': '14',
'children': '15',
'chill': '16',
'classical': '17',
'club': '18',
'comedy': '19',
'country': '20',
'dance': '21',
'dancehall': '22',
'death-metal': '23',
'deep-house': '24',
'detroit-techno': '25',
'disco': '26',
'disney': '27',
'drum-and-bass': '28',
'dub': '29',
'dubstep': '30',
'edm': '31',
'electro': '32',
'electronic': '33',
'emo': '34',
'folk': '35',
'forro': '36',
'french': '37',
'funk': '38',
'garage': '39',
'german': '40',
'gospel': '41',
'goth': '42',
'grindcore': '43',
'groove': '44',
'grunge': '45',
'guitar': '46',
'happy': '47',
'hard-rock': '48',
'hardcore': '49',
'hardstyle': '50',
'heavy-metal': '51',
'hip-hop': '52',
'honky-tonk': '53',
'house': '54',
'idm': '55',
'indian': '56',
'indie': '57',
'indie-pop': '58',
'industrial': '59',
'iranian': '60',
'j-dance': '61',
'j-idol': '62',
'j-pop': '63',
'j-rock': '64',
'jazz': '65',
'k-pop': '66',
'kids': '67',
'latin': '68',
'latino': '69',
'malay': '70',
'mandopop': '71',
'metal': '72',
'metalcore': '73',
'minimal-techno': '74',
'mpb': '75',
'new-age': '76',
'opera': '77',
'pagode': '78',
'party': '79',
'piano': '80',
'pop': '81',
'pop-film': '82',
'power-pop': '83',
'progressive-house': '84',
'psych-rock': '85',
'punk': '86',
'punk-rock': '87',
'r-n-b': '88',
'reggae': '89',
'reggaeton': '90',
'rock': '91',
'rock-n-roll': '92',
'rockabilly': '93',
'romance': '94',
'sad': '95',
'salsa': '96',
'samba': '97',
'sertanejo': '98',
'show-tunes': '99',
'singer-songwriter': '100',
'ska': '101',
'sleep': '102',
'songwriter': '103',
'soul': '104',
'spanish': '105',
'study': '106',
'swedish': '107',
'synth-pop': '108',
'tango': '109',
'techno': '110',
'trance': '111',
'trip-hop': '112',
'turkish': '113',
'world-music': '114'}

# %%
features= data[[ 'duration_ms', 'danceability', 'speechiness', 'tempo', 'popularity', 'energy', 'loudness', 'acousticness', 'instrumentalness', 'liveness','track_genre' ]] #includes only variables that can be floats
factors_all_inc= data[['track_id', 'artists', 'track_name', 'duration_ms', 'explicit', 'danceability', 'speechiness', 'tempo', 'track_genre', 'popularity', 'energy', 'loudness', 'acousticness', 'instrumentalness', 'liveness']] #includes all factors

# %%
preprocessor= ColumnTransformer(transformers=[('num',StandardScaler(), [ 'duration_ms', 'danceability', 'speechiness', 'tempo', 'popularity', 'energy', 'loudness', 'acousticness', 'instrumentalness', 'liveness', 'track_genre' ]),('cat', OneHotEncoder(),['track_genre']),('cat', OneHotEncoder(),['track_name'])])

# %%
scaler = StandardScaler()
scaled_features= scaler.fit_transform(features)
#this code makes it so that no one factor overtakes the others when its doing comparisons
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6748\188821347.py in ?()
#       1 scaler = StandardScaler()
# ----> 2 scaled_features= scaler.fit_transform(features)
#       3 #this code makes it so that no one factor overtakes the others when its doing comparisons
#
# ~\New folder\Lib\site-packages\sklearn\utils\_set_output.py in ?(self, X, *args, **kwargs)
#     293     @wraps(f)
#     294     def wrapped(self, X, *args, **kwargs):
# --> 295         data_to_wrap = f(self, X, *args, **kwargs)
#     296         if isinstance(data_to_wrap, tuple):
#     297             # only wrap the first output for cross decomposition
#     298             return_tuple = (
#
# ~\New folder\Lib\site-packages\sklearn\base.py in ?(self, X, y, **fit_params)
#    1094                 )
#    1095
#    1096         if y is None:
# ...

# %%
X_train, X_test = train_test_split(scaled_features, test_size=.2, random_state=42) 
#tells nearest neighbor how much to use for the test and how much goes towards training the model. Random state means youll get the same split
weights={'duration_ms':.3, 'danceability':.5, 'speechiness':.25, 'tempo':.5, 'popularity':.05, 'energy':.15, 'loudness':.15, 'acousticness':.15, 'instrumentalness':.3,'track_genre':1}
model = NearestNeighbors(n_neighbors=5)
model.fit(scaled_features)
# Out:
# NearestNeighbors()

# %%
def weighted_distance(song_a, song_b, weights):
    distance=0
    for features in weights.keys():
        if features in ['duration_ms', 'danceability', 'speechiness', 'tempo', 'popularity', 'energy', 'loudness', 'acousticness', 'instrumentalness']:
            distance+= weights[features] * abs(song_a[features]-song_b[features])
        elif features== track_genre:
            if song_a[features]!=song_b[features]:
                distance+= weight[features]*1 #impacts non matching genres
    return distance

# %%
#defining the function that recomends the songs
def recommended_songs(song_index, model, data, features, weights):
    distances, indices=model.kneighbors([scaled_features[song_index]])
    recommendation=[]
    target_song=features.iloc[song_index]
    for i in range (len(indices[0])):
        if indices[0][i] != song_index:
            neighbor_song= features.iloc[indices[0][i]]
            distance= weighted_distance(target_song, neighbor_song, weights)
            recommendations.append(indices[0][i], distance)
    recommendations.sort(key=lambda x: x[1])
    print('Song recommendations for:', data.iloc[song_index]['track_name'], 'Genre:', data.iloc[song_index]['track_genre'])
    for idx, dist in recommendations[:5]:
        print('Rev recommends:', data.iloc[indices[0][i]]['track_name'], '|Artist:', data.iloc[indices[0][i]]['artists'],'|Genre:', data.iloc[indices[0][i]]['track_genre'])

# %%
#old code
#print('Song recommendations for:', data.iloc[song_index]['track_name'], 'Genre:', data.iloc[song_index]['track_genre'])
#for i in range (1, len(distances[0])):
        #print('Rev recommends:', data.iloc[indices[0][i]]['track_name'], '|Artist:', data.iloc[indices[0][i]]['artists'],'|Genre:', data.iloc[indices[0][i]]['track_genre'])

# %%
recommended_songs(2510, model, data, features, weights)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[160], line 1
# ----> 1 recommended_songs(2510, model, data, features, weights)
#
# Cell In[158], line 9, in recommended_songs(song_index, model, data, features, weights)
#       7     if indices[0][i] != song_index:
#       8         neighbor_song= features.iloc[indices[0][i]]
# ----> 9         distance= weighted_distance(target_song, neighbor_song, weights)
#      10         recommendations.append(indices[0][i], distance)
#      11 recommendations.sort(key=lambda x: x[1])
#
# Cell In[156], line 6, in weighted_distance(song_a, song_b, weights)
#       4 if features in ['duration_ms', 'danceability', 'speechiness', 'tempo', 'popularity', 'energy', 'loudness', 'acousticness', 'instrumentalness']:
#       5     distance+= weights[features] * abs(song_a[features]-song_b[features])
# ----> 6 elif features== track_genre:
# ...
